# %% [markdown]
# # Emulators: First example
#
# This example illustrates Bayesian inference on a time series, using [Adaptive Covariance MCMC](http://pints.readthedocs.io/en/latest/mcmc_samplers/adaptive_covariance_mcmc.html) with emulator neural networks .
#
# It follows on from [Sampling: First example](../sampling/first-example.ipynb)
#
# Like in the sampling example, I start by importing pints:

# %%
import pints

# %% [markdown]
# Next, I create a model class using the "Logistic" toy model included in pints:

# %%
import pints.toy as toy
model = toy.LogisticModel()

# %% [markdown]
# In order to generate some test data, I choose an arbitrary set of "true" parameters:

# %%
true_parameters = [0.015, 500]

# %% [markdown]
# And a number of time points at which to sample the time series:

# %%
import numpy as np
times = np.linspace(0, 1000, 400)

# %% [markdown]
# Using these parameters and time points, I generate an example dataset:

# %%
org_values = model.simulate(true_parameters, times)

# %% [markdown]
# And make it more realistic by adding gaussian noise:

# %%
noise = 10
values = org_values + np.random.normal(0, noise, org_values.shape)

# %% [markdown]
# Using matplotlib, I look at the noisy time series I just simulated:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4.5))
plt.xlabel('Time')
plt.ylabel('Values')
plt.plot(times, values, label='Noisy data')
plt.plot(times, org_values, lw=2, label='Noise-free data')
plt.legend()
plt.show()

# %% [markdown]
# Now, I have enough data (a model, a list of times, and a list of values) to formulate a PINTS problem:

# %%
problem = pints.SingleOutputProblem(model, times, values)

# %% [markdown]
# I now have some toy data, and a model that can be used for forward simulations. To make it into a probabilistic problem, a _noise model_ needs to be added. This can be done using the `GaussianLogLikelihood` function, which assumes independently distributed Gaussian noise over the data, and can calculate log-likelihoods:

# %%
#log_likelihood = pints.GaussianLogLikelihood(problem)
log_likelihood = pints.GaussianKnownSigmaLogLikelihood(problem, noise)

# %% [markdown]
# The resulting noise has mean zero and an unknown standard deviation. The standard deviation can be inferred along with the other parameters, meaning the number of parameters of the problem increased by one!

# %%
print('Original number of parameters: ' + str(problem.n_parameters()))
# Out:
# Original number of parameters: 2

# %%
print('New number of parameters: ' + str(log_likelihood.n_parameters()))
# Out:
# New number of parameters: 2

# %% [markdown]
# This means the vector of true parameters has to be updated:

# %%
#true_parameters += [noise]
print(true_parameters)
# Out:
# [0.015, 500]

# %% [markdown]
# This `log_likelihood` represents the _conditional probability_ $p(y|\theta)$, given a set of parameters $\theta$ and a series of $y=$ `values`, it can calculate the probability of finding those values if the real parameters are $\theta$.
#
# This can be used in a Bayesian inference scheme to find the quantity of interest:
#
# $p(\theta|y) = \frac{p(\theta)p(y|\theta)}{p(y)} \propto p(\theta)p(y|\theta)$
#
# To solve this, a _prior_ is defined, indicating an initial guess about what the parameters should be.
# Similarly as using a _log-likelihood_ (the natural logarithm of a likelihood), this is defined by using a _log-prior_. Hence, the above equation simplifies to:
#
# $\log p(\theta|y) \propto \log p(\theta) + \log p(y|\theta)$
#
# In this example, it is assumed that we don't know too much about the prior except lower and upper bounds for each variable: We assume the first model parameter is somewhere on the interval $[0.01, 0.02]$, the second model parameter on $[400, 600]$, and the standard deviation of the noise is somewhere on $[1, 100]$.

# %%
# Create bounds for our parameters and get prior
bounds = pints.RectangularBoundaries([0.01, 400], [0.02, 600])
log_prior = pints.UniformLogPrior(bounds)

# %% [markdown]
# With this prior, the numerator of Bayes' rule can be defined -- the unnormalised log posterior, $\log \left[ p(y|\theta) p(\theta) \right]$, which is the natural logarithm of the likelihood times the prior:

# %%
# Create a posterior log-likelihood (log(likelihood * prior))
log_posterior = pints.LogPosterior(log_likelihood, log_prior)

# %% [markdown]
# Finally we create a list of guesses to use as initial positions. We'll run three MCMC chains so we create three initial positions:

# %%
xs = [
    np.array(true_parameters) * 0.9,
    np.array(true_parameters) * 1.05,
    np.array(true_parameters) * 1.15,
]

# %% [markdown]
# And this gives us everything we need to run an MCMC routine:

# %%
chains = pints.mcmc_sample(log_posterior, 3, xs)
# Out:
# Using Haario-Bardenet adaptive covariance MCMC
# Generating 3 chains.
# Running in sequential mode.
# Iter. Eval. Accept.   Accept.   Accept.   Time m:s
# 0     3      0         0         0          0:00.0
# 1     6      0         0         0          0:00.0
# 2     9      0         0         0          0:00.0
# 3     12     0         0         0.25       0:00.0
# 20    63     0.0952    0         0.143      0:00.0
# 40    123    0.0732    0.0244    0.0976     0:00.0
# 60    183    0.0492    0.0164    0.0656     0:00.0
# 80    243    0.0617    0.0247    0.0617     0:00.0
# 100   303    0.0495    0.0297    0.0594     0:00.1
# 120   363    0.0413    0.0413    0.0579     0:00.1
# 140   423    0.0496    0.0355    0.0496     0:00.1
# 160   483    0.0435    0.0311    0.0497     0:00.1
# 180   543    0.0387    0.0276    0.0442     0:00.1
# Initial phase completed.
# 200   603    0.0348    0.0299    0.039801   0:00.1
# 220   663    0.0498    0.0407    0.0452     0:00.1
# 240   723    0.0788    0.0788    0.0664     0:00.1
# 260   783    0.107     0.115     0.092      0:00.1
# 280   843    0.121     0.132     0.125      0:00.2
# 300   903    0.136     0.126     0.143      0:00.2
# 320   963    0.131     0.134     0.156      0:00.2
# 340   1023   0.135     0.135     0.170088   0:00.2
# 360   1083   0.15      0.139     0.186      0:00.2
# 380   1143   0.157     0.157     0.186      0:00.2
# 400   1203   0.162     0.187     0.182      0:00.2
# 420   1263   0.175772  0.195     0.173      0:00.3
# 440   1323   0.179     0.206     0.172      0:00.3
# 460   1383   0.189     0.213     0.167      0:00.3
# 480   1443   0.195     0.216     0.162      0:00.3
# 500   1503   0.2       0.224     0.16       0:00.3
# 520   1563   0.207     0.228     0.165      0:00.3
# 540   1623   0.211     0.24      0.163      0:00.3
# 560   1683   0.212     0.241     0.166      0:00.4
# 580   1743   0.213     0.244     0.179      0:00.4
# 600   1803   0.213     0.249584  0.18802    0:00.4
# 620   1863   0.214     0.256     0.2        0:00.4
# 640   1923   0.214     0.257     0.207      0:00.4
# 660   1983   0.219     0.256     0.214826   0:00.4
# 680   2043   0.223     0.251     0.225      0:00.5
# 700   2103   0.23      0.252     0.23       0:00.5
# 720   2163   0.234     0.257     0.233      0:00.5
# 740   2223   0.232     0.256     0.24       0:00.5
# 760   2283   0.237     0.255     0.242      0:00.5
# 780   2343   0.232     0.255     0.247      0:00.5
# 800   2403   0.235     0.248     0.25       0:00.6
# 820   2463   0.231     0.246     0.251      0:00.6
# 840   2523   0.235434  0.245     0.252      0:00.6
# 9140  27423  0.235     0.232     0.238      0:07.4
# 9160  27483  0.235     0.232     0.238      0:07.4
# 9180  27543  0.235     0.232     0.238      0:07.4
# 9200  27603  0.235     0.232     0.238      0:07.4
# 9220  27663  0.236     0.232     0.238      0:07.4
# 9240  27723  0.236     0.232     0.238      0:07.5
# 9260  27783  0.236     0.232     0.238      0:07.5
# 9280  27843  0.236     0.232     0.237      0:07.5
# 9300  27903  0.236     0.232     0.237      0:07.5
# 9320  27963  0.235     0.232     0.237099   0:07.5
# 9340  28023  0.235     0.231988  0.237      0:07.5
# 9360  28083  0.235     0.232     0.237      0:07.5
# 9380  28143  0.235476  0.232     0.237      0:07.6
# 9400  28203  0.235     0.232     0.237      0:07.6
# 9420  28263  0.235     0.232     0.237236   0:07.6
# 9440  28323  0.234615  0.232     0.237      0:07.6
# 9460  28383  0.234     0.233     0.237      0:07.6
# 9480  28443  0.234258  0.232     0.237      0:07.6
# 9500  28503  0.234     0.233     0.237      0:07.6
# 9520  28563  0.234009  0.233     0.23716    0:07.7
# 9540  28623  0.234     0.233     0.237      0:07.7
# 9560  28683  0.233553  0.233     0.237      0:07.7
# 9580  28743  0.234     0.233     0.237      0:07.7
# 9600  28803  0.234     0.233     0.237      0:07.7
# 9620  28863  0.234     0.233     0.237      0:07.7
# 9640  28923  0.234     0.233     0.237      0:07.7
# 9660  28983  0.233     0.233     0.236725   0:07.7
# 9680  29043  0.233     0.233     0.237      0:07.8
# 9700  29103  0.233     0.233     0.236      0:07.8
# 9720  29163  0.233     0.233     0.237      0:07.8
# 9740  29223  0.233     0.233     0.237      0:07.8
# 9760  29283  0.233     0.233     0.237      0:07.8
# 9780  29343  0.232     0.233105  0.237      0:07.8
# 9800  29403  0.232     0.233     0.237      0:07.8
# 9820  29463  0.233     0.234     0.237      0:07.8
# 9840  29523  0.233     0.233     0.237      0:07.9
# 9860  29583  0.233     0.234     0.237      0:07.9
# 9880  29643  0.233     0.234     0.237223   0:07.9
# 9900  29703  0.233     0.234     0.237      0:07.9
# 9920  29763  0.233     0.234     0.237      0:07.9
# 9940  29823  0.233     0.233     0.237      0:07.9
# 9960  29883  0.233     0.233     0.237      0:07.9
# 9980  29943  0.233     0.233     0.236      0:08.0
# 10000 30000  0.2331    0.2336    0.2366     0:08.0
# Halting: Maximum number of iterations (10000) reached.

# %% [markdown]
# ## Using Pints' diagnostic plots to inspect the results
#
# We can take a further look at the obtained results using Pints's [diagnostic plots](http://pints.readthedocs.io/en/latest/diagnostic_plots.html).

# %% [markdown]
# First, we use the [trace](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.trace) method to see if the three chains converged to the same solution.

# %%
import pints.plot
pints.plot.trace(chains)
plt.show()

# %% [markdown]
# Based on this plot, it looks like the three chains become very similar after about 1000 iterations.
# To be safe, we throw away the first 2000 samples and continue our analysis with the first chain.

# %%
chain = chains[0]
chain = chain[2000:]

# %% [markdown]
# We can also look for autocorrelation in the chains, using the [autocorrelation()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.autocorrelation) method. If everything went well, the samples in the chain should be relatively independent, so the autocorrelation should get quite low when the `lag` on the x-axis increases.

# %%
pints.plot.autocorrelation(chain)
plt.show()

# %% [markdown]
# Now we can inspect the inferred distribution by plotting histograms:

# %%
fig, axes = pints.plot.histogram([chain], ref_parameters=true_parameters)

# Show where the sample standard deviation of the generated noise is:
noise_sample_std = np.std(values - org_values)
#axes[-1].axvline(noise_sample_std, color='orange', label='Sample standard deviation of noise')
#axes[-1].legend()

fig.set_size_inches(14, 9)
plt.show()

# %% [markdown]
# Here we've analysed each parameter in isolation, but we can also look at correlations between parameters we found using the [pairwise()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.pairwise) plot.
#
# To speed things up, we'll first apply some _thinning_ to the chain:

# %%
chain = chain[::10]

# %%
pints.plot.pairwise(chain, kde=True, ref_parameters=true_parameters)
plt.show()

# %% [markdown]
# As these plots show, we came pretty close to the original "true" values (represented by the blue line).
# But not exactly... Worse, the method seems to suggest a normal distribution but around the wrong point.
# To find out what's going on, we can plot the log-posterior function near the true parameters:

# %%
# Plot log-posterior function
fig, axes = pints.plot.function(log_posterior, true_parameters)

# Add a line showing the sample standard deviation of the generated noise
#axes[-1].axvline(noise_sample_std, color='orange', label='Sample standard deviation of noise')
#axes[-1].legend()

# Customise the figure size
fig.set_size_inches(14, 9)
plt.show()

# %% [markdown]
# As this plot (created entirely without MCMC!) shows, the MCMC method did well, but our estimate of the true parameters has become _biased_ by the stochastic noise! You can test this by increasing the number of sample points, which increases the size of the noise sample, and reduces the bias.

# %% [markdown]
# Finally, we can look at the bit that really matters: The model predictions made from models with the parameters we found (a _posterior predictive check_). Thes can be plotted using the [series()](http://pints.readthedocs.io/en/latest/diagnostic_plots.html#pints.plot.series) method.

# %%
fig, axes = pints.plot.series(chain, problem)

# Customise the plot, and add the original, noise-free data
fig.set_size_inches(12,4.5)
plt.plot(times, org_values, c='orange', label='Noise-free data')
plt.legend()
plt.show()

# %%
input_parameters = log_prior.sample(400)
input_parameters[:5]
# Out:
# array([[1.77652666e-02, 4.47197638e+02],
#        [1.95812158e-02, 4.59541154e+02],
#        [1.15366193e-02, 4.50289465e+02],
#        [1.75704362e-02, 5.76883609e+02],
#        [1.85112400e-02, 4.25583292e+02]])

# %%
likelihoods = np.apply_along_axis(log_likelihood, 1, input_parameters)
likelihoods[:5]
# Out:
# array([ -6156.84641087,  -9978.14676724, -20031.79451077, -16294.81666566,
#         -9311.48074565])

# %%
emu = pints.SingleLayerNN(log_likelihood,
                        input_parameters, 
                        likelihoods)
emu.set_parameters(neurons=10)
emu.fit(epochs=100, batch_size=2)
emu.summary()
# Out:
# Train on 320 samples, validate on 80 samples
# Epoch 1/100
# 320/320 [==============================] - 0s 990us/step - loss: 202849413.9437 - mean_absolute_error: 11792.4880 - val_loss: 229566023.0000 - val_mean_absolute_error: 12182.9899
# Epoch 2/100
# 320/320 [==============================] - 0s 379us/step - loss: 194699999.3750 - mean_absolute_error: 11441.4159 - val_loss: 220703263.7000 - val_mean_absolute_error: 11816.9470
# Epoch 3/100
# 320/320 [==============================] - 0s 332us/step - loss: 65415514.3523 - mean_absolute_error: 6160.4743 - val_loss: 80813915.8875 - val_mean_absolute_error: 6545.8498
# Epoch 89/100
# 320/320 [==============================] - 0s 332us/step - loss: 65386476.5730 - mean_absolute_error: 6154.7640 - val_loss: 80936170.9750 - val_mean_absolute_error: 6526.0460
# Epoch 90/100
# 320/320 [==============================] - 0s 334us/step - loss: 65472290.6027 - mean_absolute_error: 6177.2584 - val_loss: 80870679.7969 - val_mean_absolute_error: 6536.3732
# Epoch 91/100
# 320/320 [==============================] - 0s 333us/step - loss: 65399577.4614 - mean_absolute_error: 6156.6610 - val_loss: 80946153.2969 - val_mean_absolute_error: 6524.6174
# Epoch 92/100
# 320/320 [==============================] - 0s 325us/step - loss: 65381255.8766 - mean_absolute_error: 6157.6869 - val_loss: 80917655.8719 - val_mean_absolute_error: 6528.9041
# Epoch 93/100
# 320/320 [==============================] - 0s 331us/step - loss: 65442986.4258 - mean_absolute_error: 6182.1180 - val_loss: 80947315.3953 - val_mean_absolute_error: 6524.4560
# Epoch 94/100
# 320/320 [==============================] - 0s 331us/step - loss: 65409511.7674 - mean_absolute_error: 6149.6488 - val_loss: 80943104.5500 - val_mean_absolute_error: 6525.0362
# Epoch 95/100
# 320/320 [==============================] - 0s 349us/step - loss: 65432747.5781 - mean_absolute_error: 6161.3614 - val_loss: 81006365.1531 - val_mean_absolute_error: 6516.5165
# Epoch 96/100
# 320/320 [==============================] - 0s 331us/step - loss: 65438188.7639 - mean_absolute_error: 6163.6694 - val_loss: 80896424.1469 - val_mean_absolute_error: 6532.2375
# Epoch 97/100
# 320/320 [==============================] - 0s 334us/step - loss: 65398099.6612 - mean_absolute_error: 6160.3113 - val_loss: 80952851.3281 - val_mean_absolute_error: 6523.6940
# Epoch 98/100
# 320/320 [==============================] - 0s 329us/step - loss: 65428839.8202 - mean_absolute_error: 6152.6420 - val_loss: 80865803.9938 - val_mean_absolute_error: 6537.1608
# Epoch 99/100
# 320/320 [==============================] - 0s 337us/step - loss: 65419374.7674 - mean_absolute_error: 6159.2185 - val_loss: 80910451.5891 - val_mean_absolute_error: 6530.0241
# Epoch 100/100
# 320/320 [==============================] - 0s 332us/step - loss: 65399117.2855 - mean_absolute_error: 6168.0176 - val_loss: 80874950.1813 - val_mean_absolute_error: 6535.6731
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                30
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
emu([0.015, 500])
# Out:
# array([[-11448.239]], dtype=float32)

# %%
def surface(
        x_grid, y_grid, z_grid,
        cmap="Blues", angle=(25, 300), alpha=1.,
        fontsize=14, labelpad=10,
        title="", x_label="", y_label="", z_label="log_likelihood"):
    """
    Creates 3d contour plot given a grid for each axis.
    Arguments:
    ``x_grid``
        An NxN grid of values.
    ``y_grid``
        An NxN grid of values.
    ``z_grid``
        An NxN grid of values. z_grid determines colour.
    ``cmap``
        (Optional) Colour map used in the plot
    ``angle``
        (Optional) tuple specifying the viewing angle of the graph
    ``alpha``
        (Optional) alpha parameter of the surface
    ``fill``
        (Optional) Used to specify whether or not contour plot should be filled
        Default False.
    ``fontsize``
        (Optional) the fontsize used for labels
    ``labelpad``
        (Optional) distance of axis labels from the labels
    ``x_label``
        (Optional) The label of the x-axis
    ``y_label``
        (Optional) The label of the y-axis
    ``z_label``
        (Optional) The label of the z-axis
    Returns a ``matplotlib`` figure object and axes handle.
    """
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D 
    ax = plt.axes(projection='3d')
    # Data for a three-dimensional line
    ax.plot_surface(x_grid, y_grid, z_grid, cmap=cmap, alpha=alpha)
    ax.view_init(*angle)

    fontsize = fontsize
    labelpad = labelpad

    if title:
        plt.title(title, fontsize=fontsize)
    if x_label:
        ax.set_xlabel(x_label, fontsize=fontsize, labelpad=labelpad)
    if y_label:
        ax.set_ylabel(y_label, fontsize=fontsize, labelpad=labelpad)
    if z_label:
        ax.set_zlabel(z_label, fontsize=fontsize, labelpad=labelpad)

    return ax

# %%
test_splits = 20 # number of splits along each axis
r_grid, k_grid, test_data = pints.generate_grid(bounds.lower(), 
                                                  bounds.upper(), 
                                                  test_splits)

model_prediction = pints.predict_grid(log_likelihood, test_data)

plt.figure(figsize = (10, 5))
surface(r_grid, k_grid, model_prediction, title = "True log_likelihood",
                     x_label = "r (growth rate)",
                     y_label = "k (carrying capacity)")

# %%
emu_prediction = pints.predict_grid(emu, test_data)

plt.figure(figsize = (10, 5))
ax = surface(r_grid, 
                    k_grid, 
                    emu_prediction, 
                    title = "Single-layer NN emulator")

# %%
chain = chains[0]
emu_prediction = np.apply_along_axis(emu, 1, chain).flatten()
model_prediction = np.apply_along_axis(log_likelihood, 1, chain).flatten()
diffs = np.abs(model_prediction - emu_prediction)

iters = np.linspace(0, 10000, len(chain))
plt.figure(figsize=(10, 5))
plt.title("Emulator and model absolute differences along a chain of MCMC")
plt.xlabel("Number of iterations")
plt.ylabel("Likelihood")
plt.plot(iters, diffs, color = "Black")
plt.show()

# %%
emu2 = pints.MultiLayerNN(log_likelihood,
                        input_parameters, 
                        likelihoods)
emu2.set_parameters()
emu2.fit()
emu2.summary()
# Out:
# Train on 320 samples, validate on 80 samples
# Epoch 1/50
# 320/320 [==============================] - 1s 2ms/step - loss: 196457030.4000 - mean_absolute_error: 11509.2258 - val_loss: 221105932.8000 - val_mean_absolute_error: 11833.8305
# Epoch 2/50
# 320/320 [==============================] - 0s 81us/step - loss: 176657212.0000 - mean_absolute_error: 10567.1825 - val_loss: 171755724.8000 - val_mean_absolute_error: 9598.5564
# Epoch 3/50
# 320/320 [==============================] - 0s 82us/step - loss: 98126204.4000 - mean_absolute_error: 7063.9909 - val_loss: 82917380.8000 - val_mean_absolute_error: 7246.8053
# Epoch 4/50
# 320/320 [==============================] - 0s 87us/step - loss: 72091218.0000 - mean_absolute_error: 6912.0371 - val_loss: 82025628.8000 - val_mean_absolute_error: 6416.9361
# Epoch 5/50
# 320/320 [==============================] - 0s 81us/step - loss: 68060099.6000 - mean_absolute_error: 6029.7810 - val_loss: 83835622.4000 - val_mean_absolute_error: 6349.4367
# Epoch 6/50
# 320/320 [==============================] - 0s 76us/step - loss: 66035343.6000 - mean_absolute_error: 6210.4525 - val_loss: 80350284.8000 - val_mean_absolute_error: 6688.5365
# Epoch 7/50
# 320/320 [==============================] - 0s 84us/step - loss: 66010348.8000 - mean_absolute_error: 6248.4510 - val_loss: 80674265.6000 - val_mean_absolute_error: 6571.9324
# Epoch 8/50
# 320/320 [==============================] - 0s 84us/step - loss: 65670001.2000 - mean_absolute_error: 6121.1400 - val_loss: 81072988.8000 - val_mean_absolute_error: 6507.9434
# Epoch 9/50
# 320/320 [==============================] - 0s 77us/step - loss: 65735756.8000 - mean_absolute_error: 6184.7795 - val_loss: 80720265.6000 - val_mean_absolute_error: 6562.8196
# Epoch 10/50
# 320/320 [==============================] - 0s 76us/step - loss: 65485914.4000 - mean_absolute_error: 6140.5250 - val_loss: 81359150.4000 - val_mean_absolute_error: 6474.9806
# Epoch 11/50
# 320/320 [==============================] - 0s 78us/step - loss: 66177793.6000 - mean_absolute_error: 6251.6845 - val_loss: 80945771.2000 - val_mean_absolute_error: 6524.6565
# Epoch 12/50
# 320/320 [==============================] - 0s 73us/step - loss: 66908059.2000 - mean_absolute_error: 6105.1371 - val_loss: 80926659.2000 - val_mean_absolute_error: 6527.4647
# Epoch 13/50
# 320/320 [==============================] - 0s 78us/step - loss: 65454043.2000 - mean_absolute_error: 6212.5889 - val_loss: 80424528.0000 - val_mean_absolute_error: 6641.8871
# Epoch 14/50
# 320/320 [==============================] - 0s 75us/step - loss: 65882096.0000 - mean_absolute_error: 6189.6944 - val_loss: 80581099.2000 - val_mean_absolute_error: 6592.5036
# Epoch 15/50
# 320/320 [==============================] - 0s 75us/step - loss: 65693984.8000 - mean_absolute_error: 6243.6939 - val_loss: 82102286.4000 - val_mean_absolute_error: 6411.2858
# Epoch 16/50
# 320/320 [==============================] - 0s 75us/step - loss: 66683757.8000 - mean_absolute_error: 6061.0424 - val_loss: 80724971.2000 - val_mean_absolute_error: 6561.9066
# Epoch 17/50
# 320/320 [==============================] - 0s 78us/step - loss: 66075994.0000 - mean_absolute_error: 6334.6421 - val_loss: 80586592.0000 - val_mean_absolute_error: 6591.1799
# Epoch 18/50
# 320/320 [==============================] - 0s 72us/step - loss: 65394364.6000 - mean_absolute_error: 6135.1274 - val_loss: 81984081.6000 - val_mean_absolute_error: 6420.0452
# Epoch 19/50
# 320/320 [==============================] - 0s 75us/step - loss: 66530182.4000 - mean_absolute_error: 6161.3752 - val_loss: 80363360.0000 - val_mean_absolute_error: 6676.1641
# Epoch 20/50
# 320/320 [==============================] - 0s 72us/step - loss: 66719001.6000 - mean_absolute_error: 6347.3975 - val_loss: 84030473.6000 - val_mean_absolute_error: 6344.8941
# Epoch 21/50
# 320/320 [==============================] - 0s 73us/step - loss: 66600630.4000 - mean_absolute_error: 6104.0596 - val_loss: 80920416.0000 - val_mean_absolute_error: 6528.4223
# Epoch 22/50
# 320/320 [==============================] - 0s 73us/step - loss: 65980426.4000 - mean_absolute_error: 6249.1195 - val_loss: 80418384.0000 - val_mean_absolute_error: 6644.5408
# Epoch 23/50
# 320/320 [==============================] - 0s 74us/step - loss: 65658016.8000 - mean_absolute_error: 6145.4161 - val_loss: 81581312.0000 - val_mean_absolute_error: 6452.5450
# Epoch 24/50
# 320/320 [==============================] - 0s 75us/step - loss: 65511296.8000 - mean_absolute_error: 6126.1273 - val_loss: 81121612.8000 - val_mean_absolute_error: 6501.9266
# Epoch 25/50
# 320/320 [==============================] - 0s 74us/step - loss: 65595314.0000 - mean_absolute_error: 6213.6872 - val_loss: 80421496.0000 - val_mean_absolute_error: 6643.1270
# Epoch 26/50
# 320/320 [==============================] - 0s 73us/step - loss: 65717386.4000 - mean_absolute_error: 6137.4078 - val_loss: 81824313.6000 - val_mean_absolute_error: 6432.3986
# Epoch 27/50
# 320/320 [==============================] - 0s 72us/step - loss: 65655923.8000 - mean_absolute_error: 6200.2627 - val_loss: 80556827.2000 - val_mean_absolute_error: 6598.4389
# Epoch 28/50
# 320/320 [==============================] - 0s 74us/step - loss: 65530320.4000 - mean_absolute_error: 6145.4723 - val_loss: 81123107.2000 - val_mean_absolute_error: 6501.7422
# Epoch 29/50
# 320/320 [==============================] - 0s 75us/step - loss: 65805984.0000 - mean_absolute_error: 6191.8230 - val_loss: 80404651.2000 - val_mean_absolute_error: 6650.9549
# Epoch 30/50
# 320/320 [==============================] - 0s 73us/step - loss: 65960018.8000 - mean_absolute_error: 6172.8521 - val_loss: 81201638.4000 - val_mean_absolute_error: 6492.4373
# Epoch 31/50
# 320/320 [==============================] - 0s 74us/step - loss: 65574288.4000 - mean_absolute_error: 6188.2491 - val_loss: 80997347.2000 - val_mean_absolute_error: 6517.6646
# Epoch 32/50
# 320/320 [==============================] - 0s 70us/step - loss: 65918150.8000 - mean_absolute_error: 6257.0045 - val_loss: 81902955.2000 - val_mean_absolute_error: 6426.2354
# Epoch 33/50
# 320/320 [==============================] - 0s 73us/step - loss: 66107228.4000 - mean_absolute_error: 6107.1305 - val_loss: 81727398.4000 - val_mean_absolute_error: 6440.2156
# Epoch 34/50
# 320/320 [==============================] - 0s 72us/step - loss: 65663446.4000 - mean_absolute_error: 6135.4376 - val_loss: 80336201.6000 - val_mean_absolute_error: 6717.3041
# Epoch 35/50
# 320/320 [==============================] - 0s 72us/step - loss: 65830266.4000 - mean_absolute_error: 6308.8844 - val_loss: 82677315.2000 - val_mean_absolute_error: 6379.7710
# Epoch 36/50
# 320/320 [==============================] - 0s 75us/step - loss: 67321666.0000 - mean_absolute_error: 6053.0709 - val_loss: 80558729.6000 - val_mean_absolute_error: 6597.9230
# Epoch 37/50
# 320/320 [==============================] - 0s 73us/step - loss: 65974686.0000 - mean_absolute_error: 6309.3296 - val_loss: 81206651.2000 - val_mean_absolute_error: 6491.8532
# Epoch 38/50
# 320/320 [==============================] - 0s 72us/step - loss: 65665557.2000 - mean_absolute_error: 6109.0221 - val_loss: 80942921.6000 - val_mean_absolute_error: 6525.0141
# Epoch 39/50
# 320/320 [==============================] - 0s 72us/step - loss: 66898656.4000 - mean_absolute_error: 6159.3745 - val_loss: 81563291.2000 - val_mean_absolute_error: 6454.2312
# Epoch 40/50
# 320/320 [==============================] - 0s 66us/step - loss: 65897596.0000 - mean_absolute_error: 6271.3012 - val_loss: 80591795.2000 - val_mean_absolute_error: 6589.8710
# Epoch 41/50
# 320/320 [==============================] - 0s 72us/step - loss: 65706112.4000 - mean_absolute_error: 6119.4564 - val_loss: 81572555.2000 - val_mean_absolute_error: 6453.3322
# Epoch 42/50
# 320/320 [==============================] - 0s 73us/step - loss: 65468227.6000 - mean_absolute_error: 6146.6025 - val_loss: 80373670.4000 - val_mean_absolute_error: 6668.3493
# Epoch 43/50
# 320/320 [==============================] - 0s 75us/step - loss: 65877384.8000 - mean_absolute_error: 6193.4730 - val_loss: 81692025.6000 - val_mean_absolute_error: 6443.1312
# Epoch 44/50
# 320/320 [==============================] - 0s 72us/step - loss: 65685129.6000 - mean_absolute_error: 6193.2381 - val_loss: 80421648.0000 - val_mean_absolute_error: 6642.8964
# Epoch 45/50
# 320/320 [==============================] - 0s 75us/step - loss: 65933179.6000 - mean_absolute_error: 6220.7844 - val_loss: 83629552.0000 - val_mean_absolute_error: 6354.4800
# Epoch 46/50
# 320/320 [==============================] - 0s 69us/step - loss: 65536238.0000 - mean_absolute_error: 6097.3326 - val_loss: 80389516.8000 - val_mean_absolute_error: 6658.6873
# Epoch 47/50
# 320/320 [==============================] - 0s 69us/step - loss: 67818273.2000 - mean_absolute_error: 6362.9852 - val_loss: 84599779.2000 - val_mean_absolute_error: 6332.2504
# Epoch 48/50
# 320/320 [==============================] - 0s 69us/step - loss: 66446256.4000 - mean_absolute_error: 6030.8438 - val_loss: 80357136.0000 - val_mean_absolute_error: 6756.3106
# Epoch 49/50
# 320/320 [==============================] - 0s 69us/step - loss: 66662984.8000 - mean_absolute_error: 6409.8802 - val_loss: 82334918.4000 - val_mean_absolute_error: 6396.0735
# Epoch 50/50
# 320/320 [==============================] - 0s 69us/step - loss: 67708006.8000 - mean_absolute_error: 6089.8452 - val_loss: 80374040.0000 - val_mean_absolute_error: 6667.9760
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 64)                192
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 82,753
# Trainable params: 82,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
emu_prediction2 = pints.predict_grid(emu2, test_data)

plt.figure(figsize = (10, 5))
ax = surface(r_grid, 
                    k_grid, 
                    emu_prediction2, 
                    title = "Multi-layer NN emulator")

# %%
chain = chains[0]
emu_prediction2 = np.apply_along_axis(emu2, 1, chain).flatten()
model_prediction2 = np.apply_along_axis(log_likelihood, 1, chain).flatten()
diffs2 = np.abs(model_prediction2 - emu_prediction2)

iters = np.linspace(0, 10000, len(chain))
plt.figure(figsize=(10, 5))
plt.title("Emulator and model absolute differences along a chain of MCMC")
plt.xlabel("Number of iterations")
plt.ylabel("Likelihood")
plt.plot(iters, diffs2, color = "Black")
plt.show()
